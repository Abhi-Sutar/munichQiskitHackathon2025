# %%
from qiskit import QuantumCircuit
from qiskit_aer import AerSimulator
from qiskit_aer.noise import NoiseModel, depolarizing_error
from qiskit.visualization import plot_histogram
from matplotlib import pyplot as plt

# %%
# Parameters 
num_qubits = 5
shots = 1024
max_iterations = 100

# %%
simulator = AerSimulator()

# Noise model
noise_model = NoiseModel()
error_1q = depolarizing_error(0.001, 1)
error_2q = depolarizing_error(0.02, 2)

noise_model.add_all_qubit_quantum_error(error_1q, ['id', 'x'])
noise_model.add_all_qubit_quantum_error(error_2q, ['cx'])

# %%
def create_crosstalk_circuit(iterations: int) -> QuantumCircuit:
    qc = QuantumCircuit(num_qubits, 1)
    qc.x(0)

    for _ in range(iterations):
        qc.id(0)         # Zamieniono z qc.i(0)
        qc.cx(1, 2)
        qc.cx(3, 4)

    qc.measure(0, 0)
    return qc

# %%
# Serching the order of the iteration when the error occure
error_iteration = None

# %%
for i in range(1, max_iterations + 1):
    circuit = create_crosstalk_circuit(i)
    job = simulator.run(circuit, shots=shots, noise_model=noise_model)
    result = job.result()
    counts = result.get_counts()

    error_rate = counts.get('0', 0) / shots

    if error_rate > 0.01:
        error_iteration = i
        print(f"❌ Błąd wykryty po {i} iteracjach (error rate = {error_rate:.2%})")
        break

if error_iteration is None:
    print(f"✅ Nie wykryto błędu do {max_iterations} iteracji.")
# Out:
# ❌ Błąd wykryty po 16 iteracjach (error rate = 1.07%)

# %%
print("\n📌 Obwód z ostatniej iteracji:")
circuit.draw(output='mpl')
# Out:
# 📌 Obwód z ostatniej iteracji:
